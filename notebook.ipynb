# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset,DataLoader
from torchvision.datasets import ImageFolder
import numpy as np
import matplotlib.pyplot as plt

# %%
import kagglehub
# You may need to re-run this cell after logging in.
path = kagglehub.competition_download('csiro-biomass')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/kagglehub/exceptions.py in kaggle_api_raise_for_status(response, resource_handle)
#      65     try:
# ---> 66         response.raise_for_status()
#      67     except requests.HTTPError as e:
#
# /usr/local/lib/python3.12/dist-packages/requests/models.py in raise_for_status(self)
#    1025         if http_error_msg:
# -> 1026             raise HTTPError(http_error_msg, response=self)
#    1027
#
# HTTPError: 401 Client Error: Unauthorized for url: https://www.kaggle.com/api/v1/competitions/data/download-all/csiro-biomass
#
# The above exception was the direct cause of the following exception:
#
# KaggleApiHTTPError                        Traceback (most recent call last)
# /tmp/ipython-input-1604928734.py in <cell line: 0>()
#       1 import kagglehub
#       2 # You may need to re-run this cell after logging in.
# ----> 3 path = kagglehub.competition_download('csiro-biomass')
#
# /usr/local/lib/python3.12/dist-packages/kagglehub/competition.py in competition_download(handle, path, force_download)
#      21     h = parse_competition_handle(handle)
#      22     logger.info(f"Downloading competition: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 23     path, _ = registry.competition_resolver(h, path, force_download=force_download)
#      24     return path
#
# /usr/local/lib/python3.12/dist-packages/kagglehub/registry.py in __call__(self, *args, **kwargs)
#      26         for impl in reversed(self._impls):
#      27             if impl.is_supported(*args, **kwargs):
# ---> 28                 return impl(*args, **kwargs)
#      29             else:
#      30                 fails.append(type(impl).__name__)
#
# /usr/local/lib/python3.12/dist-packages/kagglehub/resolver.py in __call__(self, handle, path, force_download)
#      27             Some cases where version number might be missing: Competition datasource, API-based models.
#      28         """
# ---> 29         path, version = self._resolve(handle, path, force_download=force_download)
#      30
#      31         # Note handles are immutable, so _resolve() could not have altered our reference
#
# /usr/local/lib/python3.12/dist-packages/kagglehub/http_resolver.py in _resolve(self, h, path, force_download)
#      74
#      75             try:
# ---> 76                 download_needed = api_client.download_file(url_path, archive_path, h, cached_path)
#      77             except requests.exceptions.ConnectionError:
#      78                 if cached_path:
#
# /usr/local/lib/python3.12/dist-packages/kagglehub/clients.py in download_file(self, path, out_file, resource_handle, cached_path, extract_auto_compressed_file)
#     180             timeout=(DEFAULT_CONNECT_TIMEOUT, DEFAULT_READ_TIMEOUT),
#     181         ) as response:
# --> 182             kaggle_api_raise_for_status(response, resource_handle)
#     183
#     184             total_size = int(response.headers["Content-Length"]) if "Content-Length" in response.headers else None
#
# /usr/local/lib/python3.12/dist-packages/kagglehub/exceptions.py in kaggle_api_raise_for_status(response, resource_handle)
#     104
#     105         # Default handling
# --> 106         raise KaggleApiHTTPError(message, response=response) from e
#     107
#     108
#
# KaggleApiHTTPError: 401 Client Error.
#
# You don't have permission to access resource at URL: https://www.kaggle.com/competitions/csiro-biomass
# Please make sure you are authenticated and have accepted the competition rules which can be found at this location: https://www.kaggle.com/competitions/csiro-biomass/rules

# %%
import kagglehub
# You may need to re-run this cell after logging in.
kagglehub.login()
path = kagglehub.competition_download('csiro-biomass')
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/kagglehub/exceptions.py in kaggle_api_raise_for_status(response, resource_handle)
#      65     try:
# ---> 66         response.raise_for_status()
#      67     except requests.HTTPError as e:
#
# /usr/local/lib/python3.12/dist-packages/requests/models.py in raise_for_status(self)
#    1025         if http_error_msg:
# -> 1026             raise HTTPError(http_error_msg, response=self)
#    1027
#
# HTTPError: 401 Client Error: Unauthorized for url: https://www.kaggle.com/api/v1/competitions/data/download-all/csiro-biomass
#
# The above exception was the direct cause of the following exception:
#
# KaggleApiHTTPError                        Traceback (most recent call last)
# /tmp/ipython-input-66580414.py in <cell line: 0>()
#       2 # You may need to re-run this cell after logging in.
#       3 kagglehub.login()
# ----> 4 path = kagglehub.competition_download('csiro-biomass')
#
# /usr/local/lib/python3.12/dist-packages/kagglehub/competition.py in competition_download(handle, path, force_download)
#      21     h = parse_competition_handle(handle)
#      22     logger.info(f"Downloading competition: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 23     path, _ = registry.competition_resolver(h, path, force_download=force_download)
#      24     return path
#
# /usr/local/lib/python3.12/dist-packages/kagglehub/registry.py in __call__(self, *args, **kwargs)
#      26         for impl in reversed(self._impls):
#      27             if impl.is_supported(*args, **kwargs):
# ---> 28                 return impl(*args, **kwargs)
#      29             else:
#      30                 fails.append(type(impl).__name__)
#
# /usr/local/lib/python3.12/dist-packages/kagglehub/resolver.py in __call__(self, handle, path, force_download)
#      27             Some cases where version number might be missing: Competition datasource, API-based models.
#      28         """
# ---> 29         path, version = self._resolve(handle, path, force_download=force_download)
#      30
#      31         # Note handles are immutable, so _resolve() could not have altered our reference
#
# /usr/local/lib/python3.12/dist-packages/kagglehub/http_resolver.py in _resolve(self, h, path, force_download)
#      74
#      75             try:
# ---> 76                 download_needed = api_client.download_file(url_path, archive_path, h, cached_path)
#      77             except requests.exceptions.ConnectionError:
#      78                 if cached_path:
#
# /usr/local/lib/python3.12/dist-packages/kagglehub/clients.py in download_file(self, path, out_file, resource_handle, cached_path, extract_auto_compressed_file)
#     180             timeout=(DEFAULT_CONNECT_TIMEOUT, DEFAULT_READ_TIMEOUT),
#     181         ) as response:
# --> 182             kaggle_api_raise_for_status(response, resource_handle)
#     183
#     184             total_size = int(response.headers["Content-Length"]) if "Content-Length" in response.headers else None
#
# /usr/local/lib/python3.12/dist-packages/kagglehub/exceptions.py in kaggle_api_raise_for_status(response, resource_handle)
#     104
#     105         # Default handling
# --> 106         raise KaggleApiHTTPError(message, response=response) from e
#     107
#     108
#
# KaggleApiHTTPError: 401 Client Error.
#
# You don't have permission to access resource at URL: https://www.kaggle.com/competitions/csiro-biomass
# Please make sure you are authenticated and have accepted the competition rules which can be found at this location: https://www.kaggle.com/competitions/csiro-biomass/rules
